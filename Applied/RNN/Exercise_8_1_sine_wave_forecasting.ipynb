# %% [markdown]
# # Exercise 8.1
# ## Sinus forecasting
# In this task, we will learn to implement RNNs in Keras.
# Therefore:
#  - Run the provided script and comment on the output.
#  - Vary the number and size of the LSTM layers and compare training time and stability of the performance.
#
# The goal of this task is to predict the next value of a sine function. This is a special case because the output of the network (the `y` value) should correponds to the next input `x` value.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
layers = keras.layers

print(keras.__version__)
# Out:
# 2026-06-11 18:27:07.935882: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3.14.1

# %% [markdown]
# ### Generation of data
# We start by creating a signal trace: `t = 0-100`, `f = sin(pi * t)`

# %%
N = 10000
t = np.linspace(0, 100, N)  # time steps
f = np.sin(np.pi * t)  # signal

# %% [markdown]
# Split into semi-redundant sub-sequences of `length = window_size + 1` and perform shuffle

# %%
window_size = 20
n = N - window_size - 1  # number of possible splits
print(f"generating {n} semi redundant sub-sequences with size {window_size+1}.")
data = np.stack([f[i: i + window_size + 1] for i in range(n)])
print(data.shape)
# Out:
# generating 9979 semi redundant sub-sequences with size 21.
# (9979, 21)

# %% [markdown]
# Finally, split the data into features. The `x` values are the first 20 data points of a sequence. The `y` value is the corresponding next value in the sequence.

# %%
X, y = np.split(data, [-1], axis=1)

# as always, another dimension is added to the input vector
# because the KERAS library also allows for multiple inputs per time step.
# In our case here, we have just one input value per time stamp.
X = X[..., np.newaxis]
print(X.shape)
print(y.shape)
print('Example:')
print('X =', X[0, :, 0])
print('y =', y[0, :])
# Out:
# (9979, 20, 1)
# (9979, 1)
# Example:
# X = [0.         0.0314139  0.06279679 0.0941177  0.1253457  0.15644998
#  0.18739983 0.21816471 0.24871423 0.27901826 0.30904688 0.33877044
#  0.36815961 0.39718538 0.42581909 0.45403249 0.48179773 0.50908739
#  0.53587454 0.56213275]
# y = [0.58783609]

# %% [markdown]
# ### Define and train RNN

# %%
z0 = layers.Input(shape=[None, 1])
z = layers.LSTM(16, unroll=True)(z0)
z = layers.Dense(1)(z)
model = keras.models.Model(inputs=z0, outputs=z)
print(model.summary())

model.compile(loss='mse', optimizer='adam')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781202429.308096   10022 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15102 MB memory:  -> device: 0, name: AMD Radeon RX 6950 XT, pci bus id: 0000:03:00.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 16)             │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,169 (4.57 KB)
#  Trainable params: 1,169 (4.57 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
results = model.fit(X, y,
    epochs=60,
    batch_size=32,
    verbose=2,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(factor=0.67, patience=3, verbose=1, min_lr=1E-5),
        keras.callbacks.EarlyStopping(patience=4, verbose=1)])

# asdf
# Out:
# Epoch 1/60
# 2026-06-11 18:27:10.860517: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f1b5c0050e0 initialized for platform ROCM (this does not guarantee that XLA will be used). Devices:
# 2026-06-11 18:27:10.860527: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): AMD Radeon RX 6950 XT, AMDGPU ISA version: gfx1030
# 2026-06-11 18:27:10.891013: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1781202433.579330   10220 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 281/281 - 9s - 31ms/step - loss: 0.0381 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 2/60
# 281/281 - 1s - 3ms/step - loss: 3.9327e-04 - val_loss: 1.2948e-04 - learning_rate: 0.0010
# Epoch 3/60
# 281/281 - 1s - 3ms/step - loss: 6.0736e-05 - val_loss: 2.9449e-05 - learning_rate: 0.0010
# Epoch 4/60
# 281/281 - 1s - 3ms/step - loss: 2.5728e-05 - val_loss: 2.1306e-05 - learning_rate: 0.0010
# Epoch 5/60
# 281/281 - 1s - 3ms/step - loss: 1.9474e-05 - val_loss: 1.7534e-05 - learning_rate: 0.0010
# Epoch 6/60
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0006700000318232924.
# 281/281 - 1s - 3ms/step - loss: 1.7165e-05 - val_loss: 1.4870e-05 - learning_rate: 0.0010
# Epoch 7/60
# 281/281 - 1s - 3ms/step - loss: 1.3590e-05 - val_loss: 1.2068e-05 - learning_rate: 6.7000e-04
# Epoch 8/60
# 281/281 - 1s - 3ms/step - loss: 1.2681e-05 - val_loss: 1.2903e-05 - learning_rate: 6.7000e-04
# Epoch 9/60
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0004489000252215192.
# 281/281 - 1s - 3ms/step - loss: 1.1048e-05 - val_loss: 1.1502e-05 - learning_rate: 6.7000e-04
# Epoch 10/60
# 281/281 - 1s - 3ms/step - loss: 9.6357e-06 - val_loss: 9.6836e-06 - learning_rate: 4.4890e-04
# Epoch 11/60
# 281/281 - 1s - 3ms/step - loss: 9.0841e-06 - val_loss: 8.9915e-06 - learning_rate: 4.4890e-04
# Epoch 12/60
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0003007630087086.
# 281/281 - 1s - 3ms/step - loss: 8.0301e-06 - val_loss: 7.9348e-06 - learning_rate: 4.4890e-04
# Epoch 13/60
# 281/281 - 1s - 3ms/step - loss: 7.4620e-06 - val_loss: 6.8075e-06 - learning_rate: 3.0076e-04
# Epoch 14/60
# 281/281 - 1s - 3ms/step - loss: 6.7767e-06 - val_loss: 6.7051e-06 - learning_rate: 3.0076e-04
# Epoch 15/60
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002015112101798877.
# 281/281 - 1s - 3ms/step - loss: 6.5389e-06 - val_loss: 6.8157e-06 - learning_rate: 3.0076e-04
# Epoch 16/60
# 281/281 - 1s - 3ms/step - loss: 5.9417e-06 - val_loss: 5.4767e-06 - learning_rate: 2.0151e-04
# Epoch 17/60
# 281/281 - 1s - 3ms/step - loss: 5.7321e-06 - val_loss: 6.1344e-06 - learning_rate: 2.0151e-04
# Epoch 18/60
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00013501251160050743.
# 281/281 - 1s - 3ms/step - loss: 5.5041e-06 - val_loss: 5.1840e-06 - learning_rate: 2.0151e-04
# Epoch 19/60
# 281/281 - 1s - 3ms/step - loss: 4.9502e-06 - val_loss: 4.7014e-06 - learning_rate: 1.3501e-04
# Epoch 20/60
# 281/281 - 1s - 3ms/step - loss: 4.6874e-06 - val_loss: 4.5133e-06 - learning_rate: 1.3501e-04
# Epoch 21/60
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.04583813098725e-05.
# 281/281 - 1s - 3ms/step - loss: 4.5434e-06 - val_loss: 4.2129e-06 - learning_rate: 1.3501e-04
# Epoch 22/60
# 281/281 - 1s - 3ms/step - loss: 4.2333e-06 - val_loss: 4.0859e-06 - learning_rate: 9.0458e-05
# Epoch 23/60
# 281/281 - 1s - 3ms/step - loss: 4.0616e-06 - val_loss: 4.1155e-06 - learning_rate: 9.0458e-05
# Epoch 24/60
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.060711421014276e-05.
# 281/281 - 1s - 3ms/step - loss: 3.9346e-06 - val_loss: 3.6210e-06 - learning_rate: 9.0458e-05
# Epoch 25/60
# 281/281 - 1s - 3ms/step - loss: 3.7291e-06 - val_loss: 3.4916e-06 - learning_rate: 6.0607e-05
# Epoch 26/60
# 281/281 - 1s - 3ms/step - loss: 3.6181e-06 - val_loss: 3.5685e-06 - learning_rate: 6.0607e-05
# Epoch 27/60
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.060676725202939e-05.
# 281/281 - 1s - 3ms/step - loss: 3.4882e-06 - val_loss: 3.5345e-06 - learning_rate: 6.0607e-05
# Epoch 28/60
# 281/281 - 1s - 3ms/step - loss: 3.3355e-06 - val_loss: 3.3923e-06 - learning_rate: 4.0607e-05
# Epoch 29/60
# 281/281 - 1s - 3ms/step - loss: 3.2742e-06 - val_loss: 3.0891e-06 - learning_rate: 4.0607e-05
# Epoch 30/60
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.720653359574499e-05.
# 281/281 - 1s - 3ms/step - loss: 3.1861e-06 - val_loss: 3.0471e-06 - learning_rate: 4.0607e-05
# Epoch 31/60
# 281/281 - 1s - 3ms/step - loss: 3.0347e-06 - val_loss: 2.9943e-06 - learning_rate: 2.7207e-05
# Epoch 32/60
# 281/281 - 1s - 3ms/step - loss: 3.0145e-06 - val_loss: 2.9319e-06 - learning_rate: 2.7207e-05
# Epoch 33/60
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.8228377484774683e-05.
# 281/281 - 1s - 3ms/step - loss: 2.9005e-06 - val_loss: 2.7879e-06 - learning_rate: 2.7207e-05
# Epoch 34/60
# 281/281 - 1s - 3ms/step - loss: 2.8319e-06 - val_loss: 2.7858e-06 - learning_rate: 1.8228e-05
# Epoch 35/60
# 281/281 - 1s - 3ms/step - loss: 2.7951e-06 - val_loss: 2.8763e-06 - learning_rate: 1.8228e-05
# Epoch 36/60
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.2213012305437588e-05.
# 281/281 - 1s - 3ms/step - loss: 2.7639e-06 - val_loss: 2.7954e-06 - learning_rate: 1.8228e-05
# Epoch 37/60
# 281/281 - 1s - 3ms/step - loss: 2.6684e-06 - val_loss: 2.6075e-06 - learning_rate: 1.2213e-05
# Epoch 38/60
# 281/281 - 1s - 3ms/step - loss: 2.6214e-06 - val_loss: 2.6433e-06 - learning_rate: 1.2213e-05
# Epoch 39/60
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-05.
# 281/281 - 1s - 3ms/step - loss: 2.6144e-06 - val_loss: 2.6719e-06 - learning_rate: 1.2213e-05
# Epoch 40/60
# 281/281 - 1s - 3ms/step - loss: 2.5714e-06 - val_loss: 2.5355e-06 - learning_rate: 1.0000e-05
# Epoch 41/60
# 281/281 - 1s - 3ms/step - loss: 2.5258e-06 - val_loss: 2.5100e-06 - learning_rate: 1.0000e-05
# Epoch 42/60
# 281/281 - 1s - 3ms/step - loss: 2.5009e-06 - val_loss: 2.4848e-06 - learning_rate: 1.0000e-05
# Epoch 43/60
# 281/281 - 1s - 3ms/step - loss: 2.4654e-06 - val_loss: 2.4444e-06 - learning_rate: 1.0000e-05
# Epoch 44/60
# 281/281 - 1s - 3ms/step - loss: 2.4334e-06 - val_loss: 2.3910e-06 - learning_rate: 1.0000e-05
# Epoch 45/60
# 281/281 - 1s - 3ms/step - loss: 2.4089e-06 - val_loss: 2.3957e-06 - learning_rate: 1.0000e-05
# Epoch 46/60
# 281/281 - 1s - 3ms/step - loss: 2.3764e-06 - val_loss: 2.3558e-06 - learning_rate: 1.0000e-05
# Epoch 47/60
# 281/281 - 1s - 3ms/step - loss: 2.3342e-06 - val_loss: 2.2981e-06 - learning_rate: 1.0000e-05
# Epoch 48/60
# 281/281 - 1s - 3ms/step - loss: 2.3106e-06 - val_loss: 2.2749e-06 - learning_rate: 1.0000e-05
# Epoch 49/60
# 281/281 - 1s - 3ms/step - loss: 2.2983e-06 - val_loss: 2.2417e-06 - learning_rate: 1.0000e-05
# Epoch 50/60
# 281/281 - 1s - 3ms/step - loss: 2.2555e-06 - val_loss: 2.1993e-06 - learning_rate: 1.0000e-05
# Epoch 51/60
# 281/281 - 1s - 3ms/step - loss: 2.2229e-06 - val_loss: 2.1638e-06 - learning_rate: 1.0000e-05
# Epoch 52/60
# 281/281 - 1s - 3ms/step - loss: 2.1860e-06 - val_loss: 2.2271e-06 - learning_rate: 1.0000e-05
# Epoch 53/60
# 281/281 - 1s - 3ms/step - loss: 2.1685e-06 - val_loss: 2.1307e-06 - learning_rate: 1.0000e-05
# Epoch 54/60
# 281/281 - 1s - 3ms/step - loss: 2.1281e-06 - val_loss: 2.0784e-06 - learning_rate: 1.0000e-05
# Epoch 55/60
# 281/281 - 1s - 3ms/step - loss: 2.0962e-06 - val_loss: 2.0599e-06 - learning_rate: 1.0000e-05
# Epoch 56/60
# 281/281 - 1s - 3ms/step - loss: 2.0752e-06 - val_loss: 2.0175e-06 - learning_rate: 1.0000e-05
# Epoch 57/60
# 281/281 - 1s - 3ms/step - loss: 2.0389e-06 - val_loss: 2.0578e-06 - learning_rate: 1.0000e-05
# Epoch 58/60
# 281/281 - 1s - 3ms/step - loss: 2.0167e-06 - val_loss: 2.1127e-06 - learning_rate: 1.0000e-05
# Epoch 59/60
# 281/281 - 1s - 3ms/step - loss: 2.0006e-06 - val_loss: 1.9644e-06 - learning_rate: 1.0000e-05
# Epoch 60/60
# 281/281 - 1s - 3ms/step - loss: 1.9730e-06 - val_loss: 1.9235e-06 - learning_rate: 1.0000e-05

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.ylabel('loss')
plt.yscale("log")
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.tight_layout()

# %% [markdown]
# ### Evaluate the model
# Investigate the forecasting capabilities of the model.

# %%
def predict_next_k(model, window, k=10):
    """Predict next k steps for the given model and starting sequence """
    x = window[np.newaxis, :, np.newaxis]  # initial input
    y = np.zeros(k)
    for i in range(k):
        pred = model.predict(x, verbose=0)

        # fix to extract only the raw scalar value from the prediction
        y[i] = pred.item()

        # create the new input including the last prediction
        x = np.roll(x, -1, axis=1)  # shift all inputs 1 step to the left
        x[:, -1] = y[i]  # add latest prediction to end
    return y

# %%
def plot_prediction(i0=0, k=500):
    """ Predict and plot the next k steps for an input starting at i0 """
    y0 = f[i0: i0 + window_size]  # starting window (input)
    y1 = predict_next_k(model, y0, k)  # predict next k steps

    t0 = t[i0: i0 + window_size]
    t1 = t[i0 + window_size: i0 + window_size + k]

    plt.figure(figsize=(12, 4))
    plt.plot(t, f, label='data')
    plt.plot(t0, y0, color='C1', lw=3, label='prediction')
    plt.plot(t1, y1, color='C1', ls='--')
    plt.xlim(0, 10)
    plt.legend()
    plt.xlabel('$t$')
    plt.ylabel('$f(t)$')

# %%
plot_prediction(12)

# %%
plot_prediction(85)

# %%
plot_prediction(115)
