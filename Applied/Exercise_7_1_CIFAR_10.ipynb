# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tabulate import tabulate
layers = tf.keras.layers

# %% [markdown]
# The code block below defines a few helper functions to visualize the results. You do not need to touch them.

# %%
def plot_examples(X, Y, n=10):
    """ Plot the first n examples for each of the 10 classes in the CIFAR dataset X, Y """
    fig, axes = plt.subplots(n, 10, figsize=(10, n))
    for l in range(10):
        axes[0, l].set_title(cifar10_labels[l], fontsize="smaller")
        m = np.squeeze(Y) == l  # boolean mask: True for all images of label l
        for i in range(n):
            image = X[m][i].astype("uint8")  # imshow expects uint8
            ax = axes[i, l]
            ax.imshow(image, origin="upper")
            ax.set(xticks=[], yticks=[])
    return fig, ax


def plot_prediction(X, Y, Y_predict):
    """
    Plot image X along with predicted probabilities Y_predict.
    X: CIFAR image, shape = (32, 32, 3)
    Y: CIFAR label, one-hot encoded, shape = (10)
    Y_predict: predicted probabilities, shape = (10)
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))

    # plot image
    ax1.imshow(X.astype("uint8"), origin="upper")
    ax1.set(xticks=[], yticks=[])

    # plot probabilities
    ax2.barh(np.arange(10), Y_predict, align="center")
    ax2.set(xlim=(0, 1), xlabel="Score", yticks=[])
    for i in range(10):
        c = "red" if (i == np.argmax(Y)) else "black"
        ax2.text(0.05, i, cifar10_labels[i].capitalize(), ha="left", va="center", color=c)



def plot_confusion(Y_true, Y_predict):
    """
    Plot confusion matrix
    Y_true:    array of true classifications (0-9), shape = (N)
    Y_predict: array of predicted classifications (0-9), shape = (N)
    """
    C = np.histogram2d(Y_true, Y_predict, bins=np.linspace(-0.5, 9.5, 11))[0]
    Cn = C / np.sum(C, axis=1)

    fig = plt.figure()
    plt.imshow(Cn, interpolation="nearest", vmin=0, vmax=1, cmap=plt.cm.YlGnBu)
    plt.colorbar()
    plt.xlabel("prediction")
    plt.ylabel("truth")
    plt.xticks(range(10), cifar10_labels, rotation="vertical")
    plt.yticks(range(10), cifar10_labels)
    for x in range(10):
        for y in range(10):
            plt.annotate("%i" % C[x, y], xy=(y, x), ha="center", va="center")

# %% [markdown]
# First we load and preprocess CIFAR-10 data. The imagages are 32x32 pixels and have three color channels (red, green blue).

# %%
# X: images, Y: labels
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

print("images, shape = ", x_train.shape)
print("labels, shape = ", y_train.shape)

cifar10_labels = np.array([
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'])
# Out:
# images, shape =  (50000, 32, 32, 3)
# labels, shape =  (50000, 1)

# %%
# Hint: To plot example images, you can use the plot examples function
plot_examples(x_train, y_train)
# Out:
# (<Figure size 1000x1000 with 100 Axes>, <Axes: >)

# %%
# convert labels ("0"-"9") to one-hot encodings, "0" = (1, 0, ... 0) and so on
y_train_onehot = tf.keras.utils.to_categorical(y_train, 10)
y_test_onehot = tf.keras.utils.to_categorical(y_test, 10)[:8000]
y_valid_onehot = tf.keras.utils.to_categorical(y_test, 10)[8000:]

# Hint: normalize the data
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0
# Hint: use 20% of the test data for validation
x_valid_norm = x_test_norm[8000:]
x_test_norm = x_test_norm[:8000]

# %% [markdown]
# We start with a fully connected network

# %%
# ----------------------------------------------------------
# Define model
# ----------------------------------------------------------
model = tf.keras.models.Sequential(
    [
        layers.Flatten(input_shape=(32, 32, 3)),  # (32,32,3) --> (3072)
        # this time the flatten operation is directly integrated into the network
        # structure so that we can use the same input data later for a convolutional neural network.
        layers.Dense(100, activation="leaky_relu"),  # (3072) --> (100)
        layers.Dense(10, activation="softmax")  # (100) --> (10)
        # Hint: remember that the output layer should have 10 nodes with a softmax activation
    ],
    name="nn",
)

print(model.summary())
# Out:
# /Users/frederikzielke/miniforge3/envs/deep-learning/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "nn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 100)            │       307,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 308,310 (1.18 MB)
#  Trainable params: 308,310 (1.18 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# ----------------------------------------------------------
# Training
# ----------------------------------------------------------
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()],
)

model.fit(
    x_train_norm,
    y_train_onehot,
    batch_size=32,
    epochs=20, # train at least for 20 epochs
    verbose=2,
    validation_data=(x_valid_norm, y_valid_onehot),
    callbacks=[tf.keras.callbacks.CSVLogger("history_{}.csv".format(model.name))],
)
# Out:
# Epoch 1/20
# 1563/1563 - 13s - 8ms/step - categorical_accuracy: 0.3169 - loss: 1.9308 - val_categorical_accuracy: 0.3450 - val_loss: 1.8786
# Epoch 2/20
# 1563/1563 - 12s - 7ms/step - categorical_accuracy: 0.3707 - loss: 1.7822 - val_categorical_accuracy: 0.3795 - val_loss: 1.8006
# Epoch 3/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.3974 - loss: 1.7076 - val_categorical_accuracy: 0.3790 - val_loss: 1.7838
# Epoch 4/20
# 1563/1563 - 12s - 7ms/step - categorical_accuracy: 0.4160 - loss: 1.6531 - val_categorical_accuracy: 0.4215 - val_loss: 1.6376
# Epoch 5/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.4286 - loss: 1.6121 - val_categorical_accuracy: 0.4120 - val_loss: 1.7115
# Epoch 6/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.4400 - loss: 1.5808 - val_categorical_accuracy: 0.4105 - val_loss: 1.6381
# Epoch 7/20
# 1563/1563 - 13s - 8ms/step - categorical_accuracy: 0.4514 - loss: 1.5545 - val_categorical_accuracy: 0.4335 - val_loss: 1.5759
# Epoch 8/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.4589 - loss: 1.5326 - val_categorical_accuracy: 0.4355 - val_loss: 1.5491
# Epoch 9/20
# 1563/1563 - 11s - 7ms/step - categorical_accuracy: 0.4678 - loss: 1.5094 - val_categorical_accuracy: 0.4225 - val_loss: 1.6329
# Epoch 10/20
# 1563/1563 - 11s - 7ms/step - categorical_accuracy: 0.4743 - loss: 1.4878 - val_categorical_accuracy: 0.4690 - val_loss: 1.5283
# Epoch 11/20
# 1563/1563 - 12s - 7ms/step - categorical_accuracy: 0.4809 - loss: 1.4673 - val_categorical_accuracy: 0.4485 - val_loss: 1.5458
# Epoch 12/20
# 1563/1563 - 13s - 8ms/step - categorical_accuracy: 0.4880 - loss: 1.4490 - val_categorical_accuracy: 0.4765 - val_loss: 1.5125
# Epoch 13/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.4919 - loss: 1.4396 - val_categorical_accuracy: 0.4410 - val_loss: 1.5976
# Epoch 14/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.4967 - loss: 1.4221 - val_categorical_accuracy: 0.4450 - val_loss: 1.6250
# Epoch 15/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.5014 - loss: 1.4070 - val_categorical_accuracy: 0.4855 - val_loss: 1.4726
# Epoch 16/20
# 1563/1563 - 12s - 8ms/step - categorical_accuracy: 0.5068 - loss: 1.3964 - val_categorical_accuracy: 0.4625 - val_loss: 1.5060
# Epoch 17/20
# 1563/1563 - 11s - 7ms/step - categorical_accuracy: 0.5116 - loss: 1.3811 - val_categorical_accuracy: 0.4625 - val_loss: 1.5417
# Epoch 18/20
# 1563/1563 - 11s - 7ms/step - categorical_accuracy: 0.5142 - loss: 1.3728 - val_categorical_accuracy: 0.4600 - val_loss: 1.5094
# Epoch 19/20
# 1563/1563 - 11s - 7ms/step - categorical_accuracy: 0.5182 - loss: 1.3570 - val_categorical_accuracy: 0.4795 - val_loss: 1.4662
# Epoch 20/20
# 1563/1563 - 12s - 7ms/step - categorical_accuracy: 0.5231 - loss: 1.3499 - val_categorical_accuracy: 0.4455 - val_loss: 1.5380

# %%
# ----------------------------------------------------------
# Plots
# ----------------------------------------------------------
# training curves
history = np.genfromtxt("history_{}.csv".format(model.name), delimiter=",", names=True)


# Hint: this is how you can plot the confusion matrix.
# calculate predictions for test set
y_predict = model.predict(x_test_norm, batch_size=128)

# convert back to class labels (0-9)
y_predict_cl = np.argmax(y_predict, axis=1)
y_test_cl = np.argmax(y_test_onehot, axis=1)

# plot confusion matrix
plot_confusion(y_test_cl, y_predict_cl)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Task: plot a few examples of correctly and incorrectly classified images.
# Hint: First find the indices of correctly and incorrectly classified images:
m = y_predict_cl == y_test_cl
i0 = np.arange(8000)[~m]  # misclassified images
i1 = np.arange(8000)[m]  # correctly classified images

# original (unnormalized) test images
x_test = x_test[:8000]

# Hint: Now you can use the `plot_prediction` function to plot the images:
# plot first 10 false classifications
for i in i0[0:10]:
    plot_prediction(x_test[i], y_test_onehot[i], y_predict[i])

# %% [markdown]
# **CNN**
# In the second part of this exercise, classify the images with a CNN.

# %%
# Hint: this code snipped shows how to define convolution and maxpooling layers. For more information see
# https://keras.io/api/layers/convolution_layers/convolution2d/
# https://keras.io/api/layers/pooling_layers/max_pooling2d/
model = tf.keras.models.Sequential(
    [
        layers.Conv2D(16, kernel_size=(3, 3), padding="same", activation="relu", input_shape=(32, 32, 3)),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D((2,2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(10, activation="softmax")
    ],
    name="cnn",
)

print(model.summary())
# Out:
# /Users/frederikzielke/miniforge3/envs/deep-learning/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,570 (400.66 KB)
#  Trainable params: 102,570 (400.66 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# ----------------------------------------------------------
# Training
# ----------------------------------------------------------
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()],
)

model.fit(
    x_train_norm,
    y_train_onehot,
    batch_size=32,
    epochs=40,
    validation_data=(x_valid_norm, y_valid_onehot),
    callbacks=[tf.keras.callbacks.CSVLogger("history_{}.csv".format(model.name))],
)
# Out:
# Epoch 1/40
# 2026-06-05 14:46:01.113018: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - categorical_accuracy: 0.4129 - loss: 1.5913 - val_categorical_accuracy: 0.5325 - val_loss: 1.3218
# Epoch 2/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - categorical_accuracy: 0.5660 - loss: 1.2168 - val_categorical_accuracy: 0.6100 - val_loss: 1.1036
# Epoch 3/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.6266 - loss: 1.0543 - val_categorical_accuracy: 0.6515 - val_loss: 0.9850
# Epoch 4/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - categorical_accuracy: 0.6576 - loss: 0.9596 - val_categorical_accuracy: 0.6915 - val_loss: 0.8872
# Epoch 5/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - categorical_accuracy: 0.6867 - loss: 0.8922 - val_categorical_accuracy: 0.6925 - val_loss: 0.8704
# Epoch 6/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - categorical_accuracy: 0.7019 - loss: 0.8440 - val_categorical_accuracy: 0.7105 - val_loss: 0.8347
# Epoch 7/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7157 - loss: 0.8056 - val_categorical_accuracy: 0.7185 - val_loss: 0.8046
# Epoch 8/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - categorical_accuracy: 0.7291 - loss: 0.7693 - val_categorical_accuracy: 0.7300 - val_loss: 0.8113
# Epoch 9/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7428 - loss: 0.7329 - val_categorical_accuracy: 0.7375 - val_loss: 0.7965
# Epoch 10/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7494 - loss: 0.7077 - val_categorical_accuracy: 0.7300 - val_loss: 0.7807
# Epoch 11/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7572 - loss: 0.6865 - val_categorical_accuracy: 0.7340 - val_loss: 0.7544
# Epoch 12/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - categorical_accuracy: 0.7668 - loss: 0.6634 - val_categorical_accuracy: 0.7455 - val_loss: 0.7640
# Epoch 13/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - categorical_accuracy: 0.7720 - loss: 0.6437 - val_categorical_accuracy: 0.7465 - val_loss: 0.7482
# Epoch 14/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7755 - loss: 0.6299 - val_categorical_accuracy: 0.7500 - val_loss: 0.7387
# Epoch 15/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7820 - loss: 0.6096 - val_categorical_accuracy: 0.7350 - val_loss: 0.7736
# Epoch 16/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - categorical_accuracy: 0.7869 - loss: 0.5984 - val_categorical_accuracy: 0.7495 - val_loss: 0.7356
# Epoch 17/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - categorical_accuracy: 0.7903 - loss: 0.5895 - val_categorical_accuracy: 0.7300 - val_loss: 0.7896
# Epoch 18/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.7954 - loss: 0.5733 - val_categorical_accuracy: 0.7440 - val_loss: 0.8067
# Epoch 19/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - categorical_accuracy: 0.7994 - loss: 0.5617 - val_categorical_accuracy: 0.7625 - val_loss: 0.7579
# Epoch 20/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8031 - loss: 0.5487 - val_categorical_accuracy: 0.7565 - val_loss: 0.7522
# Epoch 21/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - categorical_accuracy: 0.8080 - loss: 0.5391 - val_categorical_accuracy: 0.7460 - val_loss: 0.7712
# Epoch 22/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8129 - loss: 0.5269 - val_categorical_accuracy: 0.7665 - val_loss: 0.7828
# Epoch 23/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8148 - loss: 0.5169 - val_categorical_accuracy: 0.7520 - val_loss: 0.7738
# Epoch 24/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8159 - loss: 0.5129 - val_categorical_accuracy: 0.7420 - val_loss: 0.8038
# Epoch 25/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8207 - loss: 0.5032 - val_categorical_accuracy: 0.7645 - val_loss: 0.7801
# Epoch 26/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - categorical_accuracy: 0.8211 - loss: 0.5018 - val_categorical_accuracy: 0.7500 - val_loss: 0.7883
# Epoch 27/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8291 - loss: 0.4785 - val_categorical_accuracy: 0.7520 - val_loss: 0.7940
# Epoch 28/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - categorical_accuracy: 0.8262 - loss: 0.4861 - val_categorical_accuracy: 0.7575 - val_loss: 0.8155
# Epoch 29/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - categorical_accuracy: 0.8290 - loss: 0.4763 - val_categorical_accuracy: 0.7535 - val_loss: 0.8427
# Epoch 30/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8287 - loss: 0.4726 - val_categorical_accuracy: 0.7660 - val_loss: 0.7719
# Epoch 31/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8333 - loss: 0.4668 - val_categorical_accuracy: 0.7600 - val_loss: 0.8189
# Epoch 32/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8329 - loss: 0.4606 - val_categorical_accuracy: 0.7435 - val_loss: 0.8392
# Epoch 33/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8357 - loss: 0.4569 - val_categorical_accuracy: 0.7615 - val_loss: 0.8032
# Epoch 34/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8362 - loss: 0.4574 - val_categorical_accuracy: 0.7420 - val_loss: 0.8647
# Epoch 35/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8385 - loss: 0.4437 - val_categorical_accuracy: 0.7605 - val_loss: 0.8018
# Epoch 36/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8419 - loss: 0.4404 - val_categorical_accuracy: 0.7590 - val_loss: 0.8645
# Epoch 37/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8445 - loss: 0.4327 - val_categorical_accuracy: 0.7635 - val_loss: 0.7936
# Epoch 38/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8437 - loss: 0.4313 - val_categorical_accuracy: 0.7430 - val_loss: 0.8749
# Epoch 39/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8447 - loss: 0.4287 - val_categorical_accuracy: 0.7505 - val_loss: 0.8190
# Epoch 40/40
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - categorical_accuracy: 0.8483 - loss: 0.4247 - val_categorical_accuracy: 0.7505 - val_loss: 0.8495

# %%
# ----------------------------------------------------------
# Plots
# ----------------------------------------------------------
# training curves
history = np.genfromtxt("history_{}.csv".format(model.name), delimiter=",", names=True)
fig, ax = plt.subplots(1,2, figsize=(12, 4))

ax[0].plot(history["epoch"], history["loss"], label="train loss")
ax[0].plot(history["epoch"], history["val_loss"], label="validation loss")
ax[0].set_xlabel("epoch")
ax[0].set_ylabel("loss")
ax[0].legend()

ax[1].plot(history["epoch"], history["categorical_accuracy"], label="train acc")
ax[1].plot(history["epoch"], history["val_categorical_accuracy"], label="validation acc")
ax[1].set_xlabel("epoch")
ax[1].set_ylabel("accuracy")
ax[1].legend()


# Hint: this is how you can plot the confusion matrix.
# calculate predictions for test set
y_predict = model.predict(x_test_norm, batch_size=128)

# convert back to class labels (0-9)
y_predict_cl = np.argmax(y_predict, axis=1)
y_test_cl = np.argmax(y_test_onehot, axis=1)

# plot confusion matrix
plot_confusion(y_test_cl, y_predict_cl)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Task: plot a few examples of correctly and incorrectly classified images.
# Hint: First find the indices of correctly and incorrectly classified images:
m = y_predict_cl == y_test_cl
i0 = np.arange(8000)[~m]  # misclassified images
i1 = np.arange(8000)[m]  # correctly classified images

# original (unnormalized) test images
x_test = x_test[:8000]

# Hint: Now you can use the `plot_prediction` function to plot the images:
# plot first 10 false classifications
for i in i0[0:10]:
    plot_prediction(x_test[i], y_test_onehot[i], y_predict[i])
